# %%
import math
train={
                'A':{'苹果':1,'香蕉':1,'西瓜':1},
                'B':{'苹果':1,'西瓜':1},
                'C':{'苹果':1,'香蕉':1,'菠萝':1},
                'D':{'香蕉':1,'葡萄':1},
                'E':{'葡萄':1,'菠萝':1},
                'F':{'香蕉':1,'西瓜':1}
            }

c = dict()##同时购买的次数
n = dict()## 购买的用户数
for u,items in train.items():## u==谁  items ==买了什么
    print('u was :',u)
    print('items was :',items)
    for i in items.keys():
        print('i 循环 开始')
        print('i was :',i)
        print('items.key() was :',items.keys())
        print('n.keys() is :',n.keys())
        
        if i not in n.keys():
            n[i] = 0 
        n[i] += 1
        print('--------------------')
        print('n.keys() is :',n.keys())
        print('n[i] was ',n[i])
        print('开始 j 循环')
        for j in items.keys():
            print('***************')
            print('items.keys():',items.keys())
            print('i was :',i)
            print('j was :',j)
            print('before progess c.keys:',c.keys())
            
           # print('before progess c[i].keys():',c[i].keys())
            if i == j:
                continue
            if i not in c.keys():
                c[i] = dict()
            if j not in c[i].keys():
                c[i][j] = 0
            c[i][j]+= 1
            print('c[i][j] was ',c[i][j])
            print('after c.keys() is :',c.keys())
            print('after c[i].keys() was ',c[i].keys())
            print('一次循环结束')
                #当用户同时购买了 i和j 则 加1
w = dict()##相似分数
for i ,related_items in c.items():
    print('\\\\\\\\\\\\\\\\\\\\\\\\\\\\')
    print('c.items',c.items())
    if i not in w.keys():
        print('i:',i)
        print('w.keys()=:',w.keys())
        w[i] = dict()
        print('w.keys() was ',w.keys)
    for j,cij in related_items.items():
       
        print('.............................')
        w[i][j] = cij/math.sqrt(n[i]*n[j])
        print('w[i][j]:',w[i][j])
        print('n[i] was :',n[i])
        print('n[j] was :',n[j])
        print('其中 n[i] 和 n[j] 是购买i商品的用户数量 j是购买j商品的用户数量')
        print('j was ', j)
        print('cij was ',cij)
# Out:
# u was : A
# items was : {'苹果': 1, '香蕉': 1, '西瓜': 1}
# i 循环 开始
# i was : 苹果
# items.key() was : dict_keys(['苹果', '香蕉', '西瓜'])
# n.keys() is : dict_keys([])
# --------------------
# n.keys() is : dict_keys(['苹果'])
# n[i] was  1
# 开始 j 循环
# ***************
# items.keys(): dict_keys(['苹果', '香蕉', '西瓜'])
# i was : 苹果
# j was : 苹果
# before progess c.keys: dict_keys([])
# ***************
# items.keys(): dict_keys(['苹果', '香蕉', '西瓜'])
# i was : 苹果
# j was : 香蕉
# before progess c.keys: dict_keys([])
# c[i][j] was  1
# after c.keys() is : dict_keys(['苹果'])
# after c[i].keys() was  dict_keys(['香蕉'])
# 一次循环结束
# ***************
# items.keys(): dict_keys(['苹果', '香蕉', '西瓜'])
# i was : 苹果
# j was : 西瓜
# before progess c.keys: dict_keys(['苹果'])
# c[i][j] was  1
# after c.keys() is : dict_keys(['苹果'])
# after c[i].keys() was  dict_keys(['香蕉', '西瓜'])
# 一次循环结束
# i 循环 开始
# i was : 香蕉
# items.key() was : dict_keys(['苹果', '香蕉', '西瓜'])
# n.keys() is : dict_keys(['苹果'])
# --------------------
# ...

# %%
print(u)
print(items)
# Out:
# F
# {'香蕉': 1, '西瓜': 1}

# %%
import math
train={
                'A':{'苹果':1,'香蕉':1,'西瓜':1},
                'B':{'苹果':1,'西瓜':1},
                'C':{'苹果':1,'香蕉':1,'菠萝':1},
                'D':{'香蕉':1,'葡萄':1},
                'E':{'葡萄':1,'菠萝':1},
                'F':{'香蕉':1,'西瓜':1}
            }

c = dict()##同时购买的次数
n = dict()## 购买的用户数
a1=b1=c1=d1=e1=f1=g1=1
for u,items in train.items():## u==谁  items ==买了什么
    print('+++++++++++')
    print('谁',u)
    print('买了什么',items)
    print('+++++++++++')
    for i in items.keys():
        print('items.keys是什么：',items.keys())
        print('i第',a1,'在items.keys里面是什么:')
        print(i)
        a1+=1
        print('+++++----------+')
        if i not in n.keys():
            print('n.keys里面是什么',n.keys())
            print('第',a1,'i在n.keys()里面是什么')
            print(i)
            print('-------+++++')
            n[i] = 0 
        n[i] += 1
        for j in items.keys():
            print('-----------')
            print('items.keys()是什么',items.keys())
            print('第',d1,'j 在 items.keys里面是什么:')
            print(j)
            d1 +=1
            print('-----------')
            if i == j:
                continue
            if i not in c.keys():
                print('c.keys是什么',c.keys)
                print('***************88')
                c[i] = dict()
            if j not in c[i].keys():
                print('c[i].keys()里面是什么',c[i].keys())
                print('在C【i】key里面的j:',j)
                print('&&&&&&&&&&')
                c[i][j] = 0
            c[i][j]+= 1
                #当用户同时购买了 i和j 则 加1
w = dict()##相似分数
for i ,related_items in c.items():
    print('((((((((((((((()))))))))))))))')
    print('在w里面的i是什么',i)
    print('related-items又是什么',related_items)
    print('((((((((((((((()))))))))))))))')
    if i not in w.keys():
        print('w.keys=',w.keys)
        print('\\\\\\\\\\\\\\')
        w[i] = dict()
    for j,cij in related_items.items():
        print('what is the j',j)
        print('what is the cij',cij)
        print('.............................')
        w[i][j] = cij/math.sqrt(n[i]*n[j])
